# %% [markdown]
# # 2.13 a

# %%
import math as mt
import numpy as np
import sympy as sp

# %% [markdown]
# # 2.13
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Obs.: A menor força necessária P será aquela que fará 90 graus com a força de 50 N (chamada de F na resolução).
#
# ![image-3.png](attachment:image-3.png)

# %%
f = 50
alpha = 180-90-25
p,r = sp.symbols('p r')
eq1 = sp.Eq(p/sp.sin(25*sp.pi/180),f/sp.sin(alpha*sp.pi/180))
sol1 = sp.solve(eq1,p)
p_value = sp.N(sol1[0])
eq2 = sp.Eq(f/sp.sin(alpha*sp.pi/180),r/sp.sin(90*sp.pi/180))
sol2 = sp.solve(eq2,r)
r_value = sp.N(sol2[0])
print(f'P = {p_value} N, R = {r_value} N')
# Out:
# P = 23.3153829077499 N, R = 55.1688959481246 N

# %% [markdown]
# # 2.14
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Assim como no problema anterior, para que a força P seja a menor possível, o ângulo formado entre ela e a força F deve ser de 90 graus
#
# ![image-3.png](attachment:image-3.png)

# %%
f = 1890
alhpa = 60
p,r = sp.symbols('p r')
eq1 = sp.Eq(p/sp.sin(60*sp.pi/180),f/sp.sin((90-alpha)*sp.pi/180))
sol1 = sp.solve(eq1,p)
p_value = sp.N(sol1[0])
eq2 = sp.Eq(f/sp.sin((90-alpha)*sp.pi/180),r/sp.sin(90*sp.pi/180))
sol2 = sp.solve(eq2,r)
r_value = sp.N(sol2[0])
print(f'P = {p_value} N, R = {r_value} N')
# Out:
# P = 3872.97038800669 N, R = 4472.12099215822 N

# %%
|
